# %% [markdown]
# # python and quandl, unemployment  data
# ---
# FRED

# %%
import quandl
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = 'mh48QNrYTcuVWizvxQ-D'
quandl.ApiConfig.verify_ssl = False

# %%
mydata= quandl.get("FRED/GDP")
mydata
# Out:
# /miniconda3/envs/JunhaPark_env_py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  23992.355
#
# [300 rows x 1 columns]

# %%
data = quandl.get_table('ZACKS/FC', ticker='AAPL')
data
# Out:
# /miniconda3/envs/JunhaPark_env_py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#      m_ticker ticker comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 1        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 2        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 3        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 4        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
#
#      per_end_date per_type per_code  per_fisc_year  ...  \
# None                                                ...
# 0      2018-12-31        Q     None           2019  ...
# 1      2018-09-30        Q     None           2018  ...
# ...

# %%
df = quandl.get(["FRED/UNRATE", "FRED/LNS14000003", "FRED/LNS14000006","FRED/LNS14000009", "FRED/LNU04032183"],trim_start="2005-1-1", trim_end="2023-8-31", collapse = 'monthly')
df.columns = ['Unemployment', 'Unemp_White', 'Unemp_Black', 'Unemp_Hispanic','Unemp_Asian']
df.tail()
# Out:
# /miniconda3/envs/JunhaPark_env_py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /miniconda3/envs/JunhaPark_env_py310/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
cols = [col for col in df.columns]
fig, ax = plt.subplots(1, 1, figsize=(14,6))
plt.style.use('fivethirtyeight')

for c in cols:
    ax.plot(c, linewidth=2, data=df)
    ax.set_title('Unemployment Rate by Race')
    plt.xlabel('Year')
    plt.ylabel('Percent')
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels,loc='upper left', prop={"size":10})    
plt.show()

# %% [markdown]
# # network with medium blog
# https://medium.com/@pragprog/table-of-contents-d2693f827738
